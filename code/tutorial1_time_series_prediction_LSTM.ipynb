# %%
import pandas
import numpy
import matplotlib.pyplot as plt

# %%
dataset = pandas.read_excel("C:/repositorios/DL_LSTM/dataset/international-airline-passengers.xls", skiprows =  14, header =0)

# %%
dataset
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Month</th>
#       <th>num_pass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1949-01-01</td>
#       <td>112</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1949-02-01</td>
#       <td>118</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1949-03-01</td>
#       <td>132</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1949-04-01</td>
#       <td>129</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1949-05-01</td>
#       <td>121</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1949-06-01</td>
#       <td>135</td>
#     </tr>
#     <tr>
# ...
